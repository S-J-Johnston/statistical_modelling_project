# %%
import scipy as sp
import numpy as np
import pandas as pd

# %%
import json
with open('dublin_v5.json') as f:
    FSQ_dublin = json.load(f)
FSQ_dublin.keys()
# Out:
# dict_keys(['results', 'context'])

# %%
FSQ_dublin['results']
type(FSQ_dublin['results'])
dublin = pd.json_normalize(FSQ_dublin, record_path='results')
dublin['categories']
type(dublin['categories'])
dublin.head()
# Out:
#                      fsq_id  \
# 0  4b044c50f964a5200b5322e3
# 1  4b2a2ceff964a520cba524e3
# 2  4c7d3c3b10916dcb4fca2896
# 3  4fdbdce5be77dde69e2f9f58
# 4  4b8149e5f964a520c49d30e3
#
#                                           categories chains  distance  \
# 0  [{'id': 13018, 'name': 'Pub', 'icon': {'prefix...     []        31
# 1  [{'id': 13016, 'name': 'Lounge', 'icon': {'pre...     []        61
# 2  [{'id': 10030, 'name': 'History Museum', 'icon...     []        97
# 3  [{'id': 17042, 'name': 'Children's Clothing St...     []       139
# 4  [{'id': 13002, 'name': 'Bakery', 'icon': {'pre...     []       142
#
#                                   link                 name       timezone  \
# 0  /v3/places/4b044c50f964a5200b5322e3  The Bull and Castle  Europe/Dublin
# 1  /v3/places/4b2a2ceff964a520cba524e3        Darkey Kellys  Europe/Dublin
# 2  /v3/places/4c7d3c3b10916dcb4fca2896             Dublinia  Europe/Dublin
# ...

# %%
dublin_concise = dublin[['categories', 'distance', 'name', 'geocodes.main.latitude', 'geocodes.main.longitude', 'location.formatted_address']]
dublin_concise.head()
# Out:
#                                           categories  distance  \
# 0  [{'id': 13018, 'name': 'Pub', 'icon': {'prefix...        31
# 1  [{'id': 13016, 'name': 'Lounge', 'icon': {'pre...        61
# 2  [{'id': 10030, 'name': 'History Museum', 'icon...        97
# 3  [{'id': 17042, 'name': 'Children's Clothing St...       139
# 4  [{'id': 13002, 'name': 'Bakery', 'icon': {'pre...       142
#
#                   name  geocodes.main.latitude  geocodes.main.longitude  \
# 0  The Bull and Castle               53.343411                -6.269951
# 1        Darkey Kellys               53.343967                -6.269851
# 2             Dublinia               53.343226                -6.272074
# 3        Tamp & Stitch               53.344673                -6.269287
# 4       Queen of Tarts               53.344209                -6.268951
#
#                           location.formatted_address
# 0          5 - 7 Lord Edward St, Dublin, Dublin City
# ...

# %%
#df.loc[df['Name'].str.contains("pokemon", case=False)]
#dublin_concise.where(dublin_concise['categories'] < 50))
#dublin_concise[‘categories’]= dublin_concise[‘categories’].apply(str)
dublin_concise['categories'] = dublin_concise['categories'].apply(str)
#dublin_concise
dublin_concise.loc[dublin_concise['categories'].str.contains("food", case=False)]

#normailze categories, retain a key, merge back together
# Out:
# /var/folders/w6/sy887bgd32s1j5gq5fj42l000000gn/T/ipykernel_3488/462738811.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dublin_concise['categories'] = dublin_concise['categories'].apply(str)
#                                            categories  distance  \
# 0   [{'id': 13018, 'name': 'Pub', 'icon': {'prefix...        31
# 1   [{'id': 13016, 'name': 'Lounge', 'icon': {'pre...        61
# 4   [{'id': 13002, 'name': 'Bakery', 'icon': {'pre...       142
# 6   [{'id': 13006, 'name': 'Beer Bar', 'icon': {'p...       189
# 8   [{'id': 13002, 'name': 'Bakery', 'icon': {'pre...       194
# 9   [{'id': 13034, 'name': 'Café', 'icon': {'prefi...       206
# 11  [{'id': 13177, 'name': 'Greek Restaurant', 'ic...       253
# ...

# %%
categories = dublin['categories']
categories[1][1]
type(categories[1][1])
categories[1][1]['name']
# Out:
# 'Pub'
