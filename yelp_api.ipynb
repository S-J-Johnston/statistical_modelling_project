# %%
import scipy as sp
import numpy as np
import pandas as pd

# %%
import requests

url = "https://api.yelp.com/v3/businesses/search?latitude=53.343504&longitude=-6.270592&radius=1000&sort_by=best_match&limit=50"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer Bz_Eh2Iu4T3_tcMGLS8cbd9Ctafvk8kAyh4HZLNfvrDEQlyNZdVhX-nmaCoff4Wzz6Gf2tSBx3zmH0XkfG2gFbZ_ejxdIiLW6hhAU0r36DXLNJkVIxu0nG3X27iLY3Yx"
}

response = requests.get(url, headers=headers)

print(response)
# Out:
# <Response [200]>

# %%
dublin_yelp = response.json()

# %%
import json
with open('dublin_yelp.json') as f:
    dublin_yelp = json.load(f)
dublin_yelp.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
pd.json_normalize(dublin_yelp, record_path = 'businesses')
dublin_yelp_df = pd.json_normalize(dublin_yelp, record_path = 'businesses')
dublin_yelp_df.head()
# Out:
#                        id                             alias  \
# 0  rKvPQZcgjrQOLRU0phPoAQ           queen-of-tarts-dublin-4
# 1  EoMjdtjMgm3sTv7dwmfHsg            the-boxty-house-dublin
# 2  fR-pJ6nUn1bjPuT6lS2bsQ            the-brazen-head-dublin
# 3  81ikZcaZdposAXoCkJzG7w           queen-of-tarts-dublin-5
# 4  htRFt8839ESFFV9Wnvu5iQ  jameson-distillery-bow-st-dublin
#
#                         name  \
# 0             Queen of Tarts
# 1            The Boxty House
# 2            The Brazen Head
# 3             Queen of Tarts
# 4  Jameson Distillery Bow St
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/kjbRj0...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/p3oq35...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/yITsjT...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/MeR_ro...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/-kY1vN...      False
#
# ...

# %%
dub_yelp_df_concise = dublin_yelp_df.drop(columns=['id', 'alias', 'image_url', 'is_closed', 'url', 'transactions', 'location.address1', 'location.address2', 'location.address3', 'location.city', 'location.zip_code', 'location.country', 'location.state', 'price', 'phone', 'display_phone'])
dub_yelp_df_concise.head()
# Out:
#                         name  review_count  \
# 0             Queen of Tarts           513
# 1            The Boxty House           936
# 2            The Brazen Head           744
# 3             Queen of Tarts           255
# 4  Jameson Distillery Bow St           550
#
#                                           categories  rating    distance  \
# 0  [{'alias': 'desserts', 'title': 'Desserts'}, {...     4.5  214.627318
# 1             [{'alias': 'irish', 'title': 'Irish'}]     4.5  608.171192
# 2  [{'alias': 'pubs', 'title': 'Pubs'}, {'alias':...     4.0  414.325559
# 3  [{'alias': 'desserts', 'title': 'Desserts'}, {...     4.5  148.657819
# 4  [{'alias': 'museums', 'title': 'Museums'}, {'a...     4.5  703.882174
#
#    coordinates.latitude  coordinates.longitude  \
# 0             53.344121              -6.267529
# 1             53.345719              -6.262216
# 2             53.344970              -6.276330
# 3             53.344400              -6.268930
# ...

# %%
type(dub_yelp_df_concise['categories'])
dub_yelp_df_concise['categories'] = dub_yelp_df_concise['categories'].apply(str)

# %%
dub_yelp_df_concise.loc[dub_yelp_df_concise['categories'].str.contains("nightclub", case=False)]
# Out:
# Empty DataFrame
# Columns: [name, review_count, categories, rating, distance, coordinates.latitude, coordinates.longitude, location.display_address]
# Index: []
